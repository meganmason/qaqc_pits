# %%
import pandas as pd
import matplotlib.pyplot as plt

# from pandas import Grouper
# from matplotlib import pyplot

# %%
path = '/Users/meganmason491/Documents/snowex/2020/timeseries/qaqc_pits/log_tracking.xlsx'

# %%
df = pd.read_excel(path, sheet_name=1)

# %%
df
# Out:
#              Location                   Site   PitID  PitCount  edits
# 0      American River            Caples Lake  CAAMCL         7    7.0
# 1         Boise River            Banner Open  IDBRBO        10    NaN
# 2         Boise River          Banner Snotel  IDBRBS        10    NaN
# 3         Boise River            Bogus Upper  IDBRBU        11    NaN
# 4         Boise River            Bogus Lower  IDBRBL         9    NaN
# 5         Boise River  Lower Deer Point Open  IDBRLO         7    NaN
# 6         Boise River  Lower Deer Point Tree  IDBRLT         7    NaN
# 7         Boise River     Mores Creek Summit  IDMCM7         1    NaN
# 8         Boise River     Mores Creek Summit  IDMCMS         1    NaN
# 9        Cameron Pass             Joe Wright  COCPJW         8    8.0
# 10       Cameron Pass         Michigan River  COCPMR         8    8.0
# 11             Fraser                 JPL #1  COFFJ1        16    NaN
# ...

# %%
df.iloc[5]

# %%
fig, ax=plt.subplots()
df.groupby('Status')['PitCount'].sum().plot(kind='bar', ax=ax)
ax.legend(['Lvl-0', 'Lvl-1', 'Lvl-2', 'Lvl-3', 'Lvl-4'])

# %%
df

# %%
# path = '/Users/meganmason491/Documents/snowex/2020/timeseries/qaqc_pits/test.txt'
# series = read_csv(path, header=0, index_col=0, parse_dates=True, squeeze=True)
# groups = series.groupby(Grouper(freq='A'))
# years = DataFrame()
# for name, group in groups:
#     years[name.year] = group.values
# years.plot(subplots=True, legend=False)
# pyplot.show()

# %%
groups = df.groupby(pd.Grouper(key="Location"))
sites = pd.DataFrame()
for name, group in groups:
    sites[name] = group.values

# %%
for studyplot in groups:
    print(studyplot)

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot
path = '/Users/meganmason491/Documents/snowex/2020/timeseries/qaqc_pits/test.txt'
series = read_csv(path, header=0, index_col=0, parse_dates=True, squeeze=True)
groups = series.groupby(Grouper(freq='A'))
years = DataFrame()
for name, group in groups:
    years[name.year] = group.values
years.plot(subplots=True, legend=False)
pyplot.show()

# %%
name.value
