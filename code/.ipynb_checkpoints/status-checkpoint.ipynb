# %%
import pandas as pd
import matplotlib.pyplot as plt

# from pandas import Grouper
# from matplotlib import pyplot

# %%
path = '/Users/meganmason491/Documents/snowex/2020/timeseries/qaqc_pits/teststatus.xlsx'

# %%
df = pd.read_excel(path)

# %%
df
# Out:
#           Location         Site   PitID       Date Not Touched Megan or Maeve  \
# 0   American River  Caples Lake  CAAMCL 2019-12-20           x            NaN
# 1   American River  Caples Lake  CAAMCL 2020-01-31           x            NaN
# 2   American River  Caples Lake  CAAMCL 2020-02-14           x            NaN
# 3   American River  Caples Lake  CAAMCL 2020-02-21         NaN              x
# 4   American River  Caples Lake  CAAMCL 2020-02-28         NaN              x
# 5   American River  Caples Lake  CAAMCL 2020-03-06         NaN              x
# 6   American River  Caples Lake  CAAMCL 2020-03-13         NaN            NaN
# 7      Boise River  Banner Open  IDBRBO 2019-12-18         NaN            NaN
# 8      Boise River  Banner Open  IDBRBO 2020-01-09         NaN            NaN
# 9      Boise River  Banner Open  IDBRBO 2020-01-23         NaN              x
# 10     Boise River  Banner Open  IDBRBO 2020-01-30         NaN              x
#
#    Needs Review ReadyForEdits  Complete
# 0           NaN           NaN       NaN
# 1           NaN           NaN       NaN
# 2           NaN           NaN       NaN
# 3           NaN           NaN       NaN
# 4           NaN           NaN       NaN
# 5             x           NaN       NaN
# 6           NaN             x       NaN
# 7           NaN             x       NaN
# 8           NaN             x       NaN
# 9           NaN           NaN       NaN
# 10          NaN           NaN       NaN

# %%
# series = read_csv('daily-minimum-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
# groups = series.groupby(Grouper(freq='A'))
# years = DataFrame()
# for name, group in groups:
# 	years[name.year] = group.values
# years.plot(subplots=True, legend=False)
# pyplot.show()

groups = df.groupby(Grouper(key="Location"))

# %%
sites = DataFrame()
for site, studyPlot in groups:
    print ('Name:', name)
    print ('Group:', group)
#     site[name.site] = group.values
# Out:
# Name: American River
# Group:          Location         Site   PitID       Date Not Touched Megan or Maeve  \
# 0  American River  Caples Lake  CAAMCL 2019-12-20           x            NaN
# 1  American River  Caples Lake  CAAMCL 2020-01-31           x            NaN
# 2  American River  Caples Lake  CAAMCL 2020-02-14           x            NaN
# 3  American River  Caples Lake  CAAMCL 2020-02-21         NaN              x
# 4  American River  Caples Lake  CAAMCL 2020-02-28         NaN              x
# 5  American River  Caples Lake  CAAMCL 2020-03-06         NaN              x
# 6  American River  Caples Lake  CAAMCL 2020-03-13         NaN            NaN
#
#   Needs Review ReadyForEdits  Complete
# 0          NaN           NaN       NaN
# 1          NaN           NaN       NaN
# 2          NaN           NaN       NaN
# 3          NaN           NaN       NaN
# 4          NaN           NaN       NaN
# 5            x           NaN       NaN
# 6          NaN             x       NaN
# Name: Boise River
# Group:        Location         Site   PitID       Date Not Touched Megan or Maeve  \
# 7   Boise River  Banner Open  IDBRBO 2019-12-18         NaN            NaN
# 8   Boise River  Banner Open  IDBRBO 2020-01-09         NaN            NaN
# 9   Boise River  Banner Open  IDBRBO 2020-01-23         NaN              x
# 10  Boise River  Banner Open  IDBRBO 2020-01-30         NaN              x
#
#    Needs Review ReadyForEdits  Complete
# 7           NaN             x       NaN
# 8           NaN             x       NaN
# 9           NaN           NaN       NaN
# 10          NaN           NaN       NaN
